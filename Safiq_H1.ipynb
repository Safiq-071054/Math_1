# %% [markdown]
# <a href="https://colab.research.google.com/github/Safiq-071054/Math_1/blob/main/Safiq_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
value_1 = 10
value_2 =20
sum = value_1 + value_2
mul = value_1 * value_2
div = value_1 / value_2
print(sum)
print (mul)
print(div)
# Out:
# 30
# 200
# 0.5

# %%
ID= "SM-ML-2026-B2-020"
Name="Safiq Kamal"
Batch= 2
Hometown="Rajshahi"

print("ID:",ID, "\n", "Name:", Name, "\t", "Batch no:", Batch, "\n", "Hometown:", Hometown)
# Out:
# ID: SM-ML-2026-B2-020
#  Name: Safiq Kamal 	 Batch no: 2
#  Hometown: Rajshahi

# %%
value_1=10
print("old value:", value_1)
value_1=100
print("new value: ", value_1)
# Out:
# old value: 10
# new value:  100

# %%
num1_str = 100
num2_str = 500
num1 = int(num1_str)
num2 = int(num2_str)
result = num1 + num2
print("First number (int):", num1)
print("Second number (int):", num2)
print("Sum:", result)
# Out:
# First number (int): 100
# Second number (int): 500
# Sum: 600

# %%
num1_str = input("Enter first number: ")
num2_str = input("Enter second number: ")
num1 = int(num1_str)
num2 = float(num2_str)
result = num1 + num2
print("First number (int):", num1)
print("Second number (int):", num2)
print("Sum:", result)
# Out:
# Enter first number: 12
# Enter second number: 12
# First number (int): 12
# Second number (int): 12.0
# Sum: 24.0

# %%
number_1 = 100
number_2 = 200
number_3 = 300
avg = (number_1 + number_2 + number_1)/3
print (avg)
average_rounded = round(avg, 2)
print("Average:", average_rounded)
# Out:
# 133.33333333333334
# Average: 133.33

# %%
while True:
    try:
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        print("Select operation:")
        print("A. Addition (+)")
        print("S. Subtraction (-)")
        print("M. Multiplication (*)")
        print("D. Division (/)")

        choice = input("Enter choice (A/S/M/D): ").upper()

        if choice == 'A':
            result = num1 + num2
            print("Result:", result)

        elif choice == 'S':
            result = num1 - num2
            print("Result:", result)

        elif choice == 'M':
            result = num1 * num2
            print("Result:", result)

        elif choice == 'D':
            if num2 != 0:
                result = num1 / num2
                print("Result:", result)
            else:
                print("Error: Division by zero is not allowed.")

        else:
            print("Invalid choice! Please select a valid operation.")

    except ValueError:
        print("Error: Please enter valid numeric values (not letters).")

    again = input("Do you want to calculate again? (Y/N): ").upper()
    if again != 'Y':
        print("Calculator exited.")
        break
# Out:
# Enter first number: 5
# Enter second number: 6
# Select operation:
# A. Addition (+)
# S. Subtraction (-)
# M. Multiplication (*)
# D. Division (/)
# Enter choice (A/S/M/D): S
# Result: -1.0

# %%
char = input("Enter a single character: ").lower()
if len(char) == 1 and char.isalpha():
    if (char == 'a' or char == 'e' or char == 'i' or char == 'o' or char == 'u'):
        print("It is a vowel.")
    else:
        print("It is a consonant.")
else:
    print("Invalid input! Please enter a single alphabet character.")
# Out:
# Enter a single character: a
# It is a vowel.

# %%
# Taking temperature input
temp = float(input("Enter temperature: "))

print("Select conversion type:")
print("C. Celsius to Fahrenheit")
print("F. Fahrenheit to Celsius")

choice = input("Enter choice (C/F): ").upper()

if choice == 'C':
    # Celsius to Fahrenheit
    result = (temp * 9/5) + 32
    print("Temperature in Fahrenheit:", round(result, 2))

elif choice == 'F':
    # Fahrenheit to Celsius
    result = (temp - 32) * 5/9
    print("Temperature in Celsius:", round(result, 2))

else:
    print("Invalid choice! Please select C or F.")
# Out:
# Enter temperature: 23
# Select conversion type:
# C. Celsius to Fahrenheit
# F. Fahrenheit to Celsius
# Enter choice (C/F): C
# Temperature in Fahrenheit: 73.4

# %%
# Taking input from user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

# Finding the largest number
if num1 >= num2 and num1 >= num3:
    largest = num1
elif num2 >= num1 and num2 >= num3:
    largest = num2
else:
    largest = num3

# Display result
print("The largest number is:", largest)
# Out:
# Enter first number: 3
# Enter second number: 4
# Enter third number: 5
# The largest number is: 5.0

# %%
# Taking input from user
N = int(input("Enter a number: "))

print("Even numbers between 1 and", N, "are:")

# Loop from 1 to N
for i in range(1, N + 1):
    if i % 2 == 0:
        print(i)
# Out:
# Enter a number: 5
# Even numbers between 1 and 5 are:
# 2
# 4

# %%
# Taking input from user
N = int(input("Enter a number: "))

total = 0

# Loop from 1 to N
for i in range(1, N + 1):
    if i % 3 == 0 or i % 5 == 0:
        total += i

# Display result
print("Sum of numbers divisible by 3 or 5:", total)
# Out:
# Enter a number: 5
# Sum of numbers divisible by 3 or 5: 8

# %%
# Taking input from user
n = int(input("Enter a number: "))

print("Multiplication table of", n)

# Loop from 1 to 10
for i in range(1, 11):
    result = n * i
    print(n, "x", i, "=", result)
# Out:
# Enter a number: 5
# Multiplication table of 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
